# %% [markdown]
# # Домашнее задание "Теория вероятности. Дискретные Случайные Величины".

# %% [markdown]
# ## Уровень 0:

# %% [markdown]
# - Задание 1:

# %% [markdown]
# Монетку подбрасывают 15 раз, найдите вероятность выпадения простого числа орлов.

# %%
from math import factorial
import numpy as np
# Теоретическая вероятность
# простые числа до 15 это: 1, 3, 5, 7, 11, 13 , т.е. 6 чисел из 15
# орел выпадает с теоретической вероятностью 1/2

n = 15 # экспериментов
p = 1/2  # выпадение орла
kk = [1, 3, 5, 7, 11, 13] # кол-во необходимых выпадений

for k in kk:
    c = factorial(n)/factorial(k)*factorial(n-k) # количество сочетаний
    p = c*np.power(p, k)*np.power(p, (n-k))
    print(f'Вероятность выпадения орла {k} раз из {n} = {p}')

# По общей формуле
p1 = 0.5
res = 0
i = 0
while i < len(kk):
    res =+ p1*kk[i]/15
    i = i + 1
print(f'\n\nПолная вероятность выпадения простого числа орлов из 15 подбрасываний: {res}')
# Out:
# Вероятность выпадения орла 1 раз из 15 = 3.4790288344812e+18
# Вероятность выпадения орла 3 раз из 15 = 1.3821518146938952e+298
# Вероятность выпадения орла 5 раз из 15 = inf
# Вероятность выпадения орла 7 раз из 15 = inf
# Вероятность выпадения орла 11 раз из 15 = inf
# Вероятность выпадения орла 13 раз из 15 = inf
#
#
# Полная вероятность выпадения простого числа орлов из 15 подбрасываний: 0.43333333333333335
# /tmp/ipykernel_1770370/3257158528.py:13: RuntimeWarning: overflow encountered in power
#   p = c*np.power(p, k)*np.power(p, (n-k))

# %% [markdown]
# - Задание 2:

# %% [markdown]
# Создайте свою дискретную случайную величину с не менее, чем 10 значениями. Просемплируйте 1000 случайных значений, постройте гистограмму плотности распределения по выборке, посчитайте среднее, дисперсию и медиану.

# %%
from scipy.stats import *
import matplotlib.pyplot as plt
from random import choice
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker


xvar = [i for i in range(10, 501, 10)]
xs = []
for i in range(1,10001,1):
    xs.append(choice(xvar))

df = pd.DataFrame(xs, columns=['x'])
# 

# the histogram of the data
plt.figure(figsize=[25,10])
plt.hist(df['x'], xvar, facecolor='green', alpha=0.75)
plt.title('origin df')
plt.grid(True)
plt.show()

a = df['x'].mean()
d = df['x'].std()**2
m = df['x'].median()
print(f'среднее - {a}, дисперсия - {d}, медианa - {m}')
# Out:
# среднее - 253.481, дисперсия - 21034.476086608658, медианa - 250.0

# %%
sample = df.sample(1000, ignore_index=True)

# the histogram of the data
plt.figure(figsize=[25,10])
plt.hist(sample['x'], xvar, facecolor='blue', alpha=0.75)
plt.title('sample df')
plt.grid(True)
plt.show()

a = sample['x'].mean()
d = sample['x'].std()**2
m = sample['x'].median()
print(f'среднее - {a}, дисперсия - {d}, медианa - {m}')
# Out:
# среднее - 253.38, дисперсия - 21947.923523523525, медианa - 260.0

# %% [markdown]
# ## Уровень 1:

# %% [markdown]
# - Задание 3:

# %% [markdown]
# Пусть брошены 3 уравновешенные монеты.
#
# Рассмотрим 3 события:
#
# A1 - монеты 1 и 2 упали одной и той же стороной;
#
# A2 - монеты 2 и 3 упали одной и той же стороной;
#
# A3 - монеты 1 и 3 упали одной и той же стороной.
#
# Покажите, почему эти 3 события (A1, A2, A3) являются попарно независимыми, но не являются независимыми в совокупности.

# %% [markdown]
# 1. вероятность каждого из событий равна (падение любой из монет "нужной" стороной)
# 2. Вероятность наступления обоих событий для каждой пары равна произведению вероятностей каждого события по отдельности
#
# Поэтому они попарно независимы
#
# 3. Для наступления всех 3х событий (все монеты падают одной стороной) их общая вероятность не равна произведению вероятностей каждого события. Каждая из величин (результатов события) определяется двуми другими.

# %% [markdown]
# - Задание 4 (формула полной вероятности):

# %% [markdown]
# В магазин привезли устройства с 3-х разных предприятий.
#
# Соотношение устройств следующее: 20% - продукция первого предприятия, 30% - продукция второго предприятия, 50% - продукция третьего предприятия; далее, 10% продукции первого предприятия высшего сорта, на втором предприятии - 5% и на третьем - 20% продукции высшего сорта.
#
# Найти вероятность того, что случайно купленная новая продукция окажется высшего сорта.

# %%
# вероятность купить продукцию от каждого из предприятий:
pa = 0.2
pb = 0.3
pc = 0.5

# вероятность купить продукцию высшего сорта в рамках предприятия
ba = 0.1
bb = 0.05
bc = 0.2


res_p = pa*ba+pb*bb+pc*bc
print(f'Итоговая вероятность купить продукцию высшего сорта: {res_p}')
# Out:
# Итоговая вероятность купить продукцию высшего сорта: 0.135
